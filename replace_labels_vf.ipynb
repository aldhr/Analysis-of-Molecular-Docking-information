# %%
files = ['REC0.csv', 'REC1.csv', 'REC2.csv', 'REC3.csv', 'REC4.csv', 'REC5.csv',
'PSC1.csv', 'PSC1H.csv', 'PSC2.csv', 'PSC2R.csv', 'PSC3.csv', 'PSC4.csv', 'PSC5.csv',
'PSC6.csv', 'PSC7.csv', 'PSC8.csv']

for f in files:
    with open(f, 'r') as file:
        filedata = file.read()

    filedata = filedata.replace("LK_01", "INH01") 
    filedata = filedata.replace("LA_14", "INH02")
    filedata = filedata.replace("LM_01", "INH03")
    filedata = filedata.replace("LN_01", "INH04")
    filedata = filedata.replace("LO_01", "INV01")
    filedata = filedata.replace("LP_10", "INV02")
    filedata = filedata.replace("LP_09", "INV03")
    filedata = filedata.replace("LQ_01", "INV04")
    filedata = filedata.replace("LR_01", "INV05")
    filedata = filedata.replace("LA_01", "RPA01")
    filedata = filedata.replace("LA_02", "RPA02")
    filedata = filedata.replace("LA_03", "RPA03")
    filedata = filedata.replace("LA_04", "RPA04")
    filedata = filedata.replace("LL_01", "RPA05")
    filedata = filedata.replace("LA_06", "RPA06")
    filedata = filedata.replace("LA_07", "RPA07")
    filedata = filedata.replace("LA_08", "RPA08")
    filedata = filedata.replace("LA_09", "RPA09")
    filedata = filedata.replace("LA_10", "RPA10")
    filedata = filedata.replace("LA_11", "RPA11")
    filedata = filedata.replace("LA_12", "RPA12")
    filedata = filedata.replace("LA_13", "RPA13")
    filedata = filedata.replace("LA_05", "RPA14")
    filedata = filedata.replace("LM_02", "RPA15")
    filedata = filedata.replace("LB_01", "RPB01")
    filedata = filedata.replace("LB_02", "RPB02")
    filedata = filedata.replace("LB_03", "RPB03")
    filedata = filedata.replace("LB_04", "RPB04")
    filedata = filedata.replace("LB_05", "RPB05")
    filedata = filedata.replace("LB_06", "RPB06")
    filedata = filedata.replace("LB_07", "RPB07")
    filedata = filedata.replace("LO_02", "RPB08")
    filedata = filedata.replace("LC_03", "RPC01")
    filedata = filedata.replace("LC_04", "RPC02")
    filedata = filedata.replace("LD_01", "RPC03")
    filedata = filedata.replace("LP_01", "RPC04")
    filedata = filedata.replace("LP_02", "RPC05")
    filedata = filedata.replace("LP_03", "RPC06")
    filedata = filedata.replace("LP_04", "RPC07")
    filedata = filedata.replace("LP_05", "RPC08")
    filedata = filedata.replace("LP_06", "RPC09")
    filedata = filedata.replace("LP_07", "RPC10")
    filedata = filedata.replace("LP_08", "RPC11")
    filedata = filedata.replace("LC_01", "RPC12")
    filedata = filedata.replace("LC_02", "RPC13")
    filedata = filedata.replace("LC_05", "RPC14")
    filedata = filedata.replace("LQ_02", "RPD01")
    filedata = filedata.replace("LE_01", "EXT01")
    filedata = filedata.replace("LE_02", "EXT02")
    filedata = filedata.replace("LE_03", "EXT03")
    filedata = filedata.replace("LF_01", "EXT04")
    filedata = filedata.replace("LG_01", "EXT05")
    filedata = filedata.replace("LH_01", "EXT06")
    filedata = filedata.replace("LI_01", "EXT07")
    filedata = filedata.replace("LJ_01", "EXT08")
    filedata = filedata.replace("LJ_02", "EXT09")
    filedata = filedata.replace("LJ_03", "EXT10")
    filedata = filedata.replace("AC_01", "ALI01")
    filedata = filedata.replace("AC_02", "ALI02")
    filedata = filedata.replace("AC_03", "ALI03")
    filedata = filedata.replace("AC_04", "ALI04")
    filedata = filedata.replace("AC_05", "ALI05")
    filedata = filedata.replace("AC_06", "ALI06")
    filedata = filedata.replace("AC_07", "ALI07")
    filedata = filedata.replace("AC_08", "ALI08")
    filedata = filedata.replace("AC_09", "ALI09")
    filedata = filedata.replace("AC_10", "ALI10")
    filedata = filedata.replace("AC_11", "ALI11")
    filedata = filedata.replace("AC_12", "ALI12")
    filedata = filedata.replace("AC_13", "ALI13")
    filedata = filedata.replace("AC_14", "ALI14")
    filedata = filedata.replace("AC_15", "ALI15")
    filedata = filedata.replace("AC_16", "ALI16")
    filedata = filedata.replace("AC_17", "ALI17")
    filedata = filedata.replace("AC_18", "ALI18")
    filedata = filedata.replace("AC_19", "ALI19")
    filedata = filedata.replace("AC_20", "ALI20")
    filedata = filedata.replace("AC_21", "ALI21")
    filedata = filedata.replace("AC_22", "ALI22")
    filedata = filedata.replace("AC_23", "ALI23")
    filedata = filedata.replace("AC_24", "ALI24")
    filedata = filedata.replace("AC_25", "ALI25")
    filedata = filedata.replace("AC_26", "ALI26")
    with open(f,'w') as file:
        file.write(filedata)
